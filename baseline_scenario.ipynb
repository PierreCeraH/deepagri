# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#url_google = 'https://docs.google.com/spreadsheets/d/1A5AznfrCyotERb1SJdoLnjoOaXNz4QRh/edit?usp=sharing&ouid=105542978511307968983&rtpof=true&sd=true'

url = '/Users/pierre/code/PierreCeraH/data-challenges/08-Projects/01/data/cleaned data/Histo_data_YieldsAreasProd.xlsx'

df = pd.read_excel(url, sheet_name='Blé tendre')
df
# Out:
#    Unnamed: 0       AIN  Unnamed: 2 Unnamed: 3     AISNE  Unnamed: 5  \
# 0       Année  Suf.(ha)  Rend(q/ha)   Prod.(t)  Suf.(ha)  Rend(q/ha)
# 1        2000     27500          74     203500    184400   82.902386
# 2        2001     28008          60     168048    167033   81.928445
# 3        2002     29017          73   211824.1    174069   84.931544
# 4        2003     24021          53   127311.3    172102          75
# 5        2004     28533          80     228264    175589   91.904635
# 6        2005     27039          68   183865.2    178097   80.884209
# 7        2006     31555          72     227196    177751   79.944979
# 8        2007     32065          62     198803    175688   75.994718
# 9        2008     32075          63   202072.5    184688    84.99686
# 10       2009     27140   69.712601     189200    173633   89.977942
# 11       2010     33300   71.964054   239640.3    177466    83.68559
# 12       2011     32500   69.815385     226900    186550   81.986695
# ...

# %%
df = df.set_index('Unnamed: 0')
df
# Out:
#                  AIN  Unnamed: 2 Unnamed: 3     AISNE  Unnamed: 5 Unnamed: 6  \
# Unnamed: 0
# Année       Suf.(ha)  Rend(q/ha)   Prod.(t)  Suf.(ha)  Rend(q/ha)   Prod.(t)
# 2000           27500          74     203500    184400   82.902386    1528720
# 2001           28008          60     168048    167033   81.928445  1368475.4
# 2002           29017          73   211824.1    174069   84.931544  1478394.9
# 2003           24021          53   127311.3    172102          75    1290765
# 2004           28533          80     228264    175589   91.904635  1613744.3
# 2005           27039          68   183865.2    178097   80.884209  1440523.5
# 2006           31555          72     227196    177751   79.944979    1421030
# 2007           32065          62     198803    175688   75.994718    1335136
# 2008           32075          63   202072.5    184688    84.99686    1569790
# 2009           27140   69.712601     189200    173633   89.977942    1562314
# ...

# %%
df = df[['TOTAL','Unnamed: 287','Unnamed: 288']]
df = df.drop('Année', axis=0)

# %%
df = df.rename_axis('Year')

# %%
df = df.rename(columns={"TOTAL":"Surfaces","Unnamed: 287": "Production", "Unnamed: 288": "Yields"})

# %%
df
# Out:
#      Surfaces  Production     Yields
# Year
# 2000  4910142  35667737.1  72.640948
# 2001  4457702  30174697.3   67.69115
# 2002  4888878  37276484.8  76.247525
# 2003  4513832  28993238.3  64.231984
# 2004  4818995  37524039.8  77.866941
# 2005  4841253    34748270  71.775365
# 2006  4778563  33159950.3  69.393142
# 2007  4766876  30666411.5  64.332304
# 2008  5044853  36757936.5  72.862255
# 2009  4711546  36069496.1  76.555543
# 2010  4898515  35486640.3   72.44367
# 2011  4990178  33970210.5  68.074146
# 2012  4860633  35502941.4  73.041806
# 2013  4983661  36870814.5  73.983392
# 2014  5010456  37466078.2  74.775785
# 2015  5161387  40944642.4  79.328759
# 2016  5131791  27560667.8  53.705749
# 2017  4962079  36559140.5  73.677063
# 2018  4880208  34045411.9  69.762215
# 2019  4998750  39516461.6  79.052686
# 2020  4260925  29177401.3  68.476684
# 2021  4973631  35409386.8  71.194238
# 2022  4923970           0          0

# %%
sns.scatterplot(x="Production", y="Yields",
                palette=sns.color_palette(["#2ecc71", "#e74c3c"]),
                data=df)
# Out:
# <AxesSubplot:xlabel='Production', ylabel='Yields'>

# %%
df_2 = df.drop(2022, axis=0)

# %%
df_2
# Out:
#      Surfaces  Production     Yields
# Year
# 2000  4910142  35667737.1  72.640948
# 2001  4457702  30174697.3   67.69115
# 2002  4888878  37276484.8  76.247525
# 2003  4513832  28993238.3  64.231984
# 2004  4818995  37524039.8  77.866941
# 2005  4841253    34748270  71.775365
# 2006  4778563  33159950.3  69.393142
# 2007  4766876  30666411.5  64.332304
# 2008  5044853  36757936.5  72.862255
# 2009  4711546  36069496.1  76.555543
# 2010  4898515  35486640.3   72.44367
# 2011  4990178  33970210.5  68.074146
# 2012  4860633  35502941.4  73.041806
# 2013  4983661  36870814.5  73.983392
# 2014  5010456  37466078.2  74.775785
# 2015  5161387  40944642.4  79.328759
# 2016  5131791  27560667.8  53.705749
# 2017  4962079  36559140.5  73.677063
# 2018  4880208  34045411.9  69.762215
# 2019  4998750  39516461.6  79.052686
# 2020  4260925  29177401.3  68.476684
# 2021  4973631  35409386.8  71.194238

# %%
sns.scatterplot(x="Production", y="Yields",
                palette=sns.color_palette(["#2ecc71", "#e74c3c"]),
                data=df_2);

# %%
sns.scatterplot(x="Year", y="Yields",
                palette=sns.color_palette(["#2ecc71", "#e74c3c"]),
                data=df_2)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Yields'>

# %%
plt.plot(df_2[['Yields']]);

# %%
sns.scatterplot(x="Year", y="Surfaces",
                palette=sns.color_palette(["#2ecc71", "#e74c3c"]),
                data=df_2)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Surfaces'>

# %%
avg_surfaces = df_2[['Surfaces']].mean()
avg_yields = df_2[['Yields']].mean()

# %%
avg_surfaces = avg_surfaces['Surfaces']

# %%
avg_surfaces
# Out:
# 4856584.2727272725

# %%
avg_yields = avg_yields['Yields']

# %%
#avg_yields en t/ha
avg_yields = avg_yields/10
avg_yields
# Out:
# 7.14142430723645

# %%
baseline_pred = (avg_surfaces * avg_yields)
#Baseline score en MlnT
baseline_pred/1_000_000
# Out:
# 34.682928975396806

# %%
avg_prod = df_2[['Production']].mean()
avg_prod = avg_prod['Production']/1_000_000

# %%
avg_prod
# Out:
# 34.706729949999996

# %%
df_3 = df.drop(2016, axis=0)

# %%
df_3 = df_3.drop(2016, axis=0)

# %%
sns.scatterplot(x="Year", y="Yields",
                palette=sns.color_palette(["#2ecc71", "#e74c3c"]),
                data=df_3)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Yields'>

# %%
avg_yields_2 = df_3[['Yields']].mean()
avg_yields_2 = avg_yields_2['Yields']
avg_yields_2
# Out:
# 72.25750470753772

# %%
baseline_pred_2 = avg_yields_2 * avg_surfaces
baseline_pred_2/1_000_000/10
# Out:
# 35.09246609491446

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, max_error

mae = mean_absolute_error(df_2['Production'], [baseline_pred for i in range(len(df_2['Production']))])
mae
# Out:
# 2725204.87489178

# %%
mae/baseline_pred
# Out:
# 0.07857481923816098
